# %%
print("Welcome Vivek")
print("Welcome Harry")
print("Welcome Manoj")
print("Welcome Siddu")
# Out:
# Welcome Vivek
# Welcome Harry
# Welcome Manoj
# Welcome Siddu

# %%
# syntax declare statement
def function_name():
    # block of code
    print("welcome")

function_name()    # calling function statement

a=10

print(a)
# Out:
# welcome
# 10

# %%
def fun():
    print("Welcome")    
fun()
fun()
fun()
fun()
# Out:
# Welcome
# Welcome
# Welcome
# Welcome

# %%
def welcomeUser(userName):
    print("Welcome:",userName)
    
welcomeUser("Vivek")
welcomeUser("harry")
welcomeUser("Manoj")
# Out:
# Welcome: Vivek
# Welcome: harry
# Welcome: Manoj

# %%
def addition(a,b):
    print(a+b)
a = 10
b = 5
addition(a,b)
addition(10,200)
# Out:
# 15
# 210

# %%
def sub(a,b):
    return a-b

a = 10
b = 5
x = sub(b,a)
print(x)
# Out:
# -5

# %%
def sub(a,b):
    if a>b:
        print("a is greater than b")
        return a-b

    print("b is greater than a")
    return b-a

a = 10
b = 50
x = sub(a,b)
print(x)
x = sub(10,20)
print(x)
# Out:
# a is greater than b
# 20

# %%
def square(num=1000):
    return num * num

print(square())
# Out:
# 25

# %%
def square(num=50):
    return num * num

print(square(int(input("Enter the number:"))))
# Out:
# 625

# %%
company = "abc"

def employee():
    name = "vijay"
    
    print("Company Name: ",company)
    print("Employee name: ",name)
employee()
# Out:
# Company Name:  abc
# Employee name:  vijay

# %%
def calculation_total(price,tax=0,discount=0):
    return price + tax - discount

result = calculation_total(1000,100,50)

print(result)
# Out:
# 1050

# %%
def execute_operation(operation,value):
    print("Value inside eo",value)
    return operation(value)

def square(x):
    print("square of x",x)
    return x*x

print(execute_operation(square,5))
# Out:
# Value inside eo 5
# square of x 5
# 25
