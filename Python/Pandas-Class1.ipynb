# %%
firstname = "vivek" # str
print(type(firstname))
lastname = "srini" 
age = 35 # int
print(type(age))
isFacuilty = True #bool
print(type(isFacuilty))
CGPA_SEM1 = 7.89 #float
print(type(CGPA_SEM1))
CGPA_SEM2 = 7.5 
print(firstname,age,CGPA_SEM1,isFacuilty)

var1 = "10"
print(type(var1))
var1 = int(var1)
print(type(var1))

# functions -> 
# methods -> object.method_name
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# vivek 35 7.89 True
# <class 'str'>
# <class 'int'>

# %%
# data structure
# 1. list[] tuple() sets() dict() (dictionary)
name = "python is powerfull"
print(name[0])
print(name[-1])
list1= [10,20,30,"vivek",100]
print(list1)
print(type(list1))
print(list1[0])
print(list1[-1]) #start, end, step - rule-1 keep the first character always
# rule 2: if step is 2, keep the first character and skip the second charater
# rule 3: if step is 3, keep the first character and skip the 2 charater from 1
# print(len(list1))
# print(list1[0:4]) 
# print(list1[0:4:1])
print(name[0::1])
# print(name[0::2])
# print(name[0::3])
print(name[::-1])
print(list1[:])
print(list1[::-1])
print(list1[::-1])
# Out:
# p
# l
# [10, 20, 30, 'vivek', 100]
# <class 'list'>
# 10
# 100
# python is powerfull
# llufrewop si nohtyp
# [10, 20, 30, 'vivek', 100]
# [100, 'vivek', 30, 20, 10]
# [100, 'vivek', 30, 20]

# %%
# positive indexing
#Index 0 1 2 3 4 5
#Char  P y t h o n

print("vivek")
# negative indexing
#Index -1 -2 -3 -4 -5 -6
#Char   n  o  h  t  y  P
# Out:
# vivek

# %%
var=[100.00,120.50,130.50,"vivek",False]
print(var[3])
# var.append("harry")
var[3]="Harry"
print(var)
# Out:
# vivek
# [100.0, 120.5, 130.5, 'Harry', False]

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
#      21     is_bool,
#      22     is_callable,
#    (...)     28     is_text,
#      29 )
# ---> 31 from pandas.errors import Pandas4Warning
#      33 # compute
#      35 use_bottleneck_doc = """
#      36 : bool
#      37     Use the bottleneck library to accelerate if it is installed,
#      38     the default is True
#      39     Valid values: False,True
#      40 """
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\errors\__init__.py:12
#       8 import ctypes
#      10 from pandas._config.config import OptionError
# ---> 12 from pandas._libs.tslibs import (
#      13     IncompatibleFrequency,
#      14     OutOfBoundsDatetime,
#      15     OutOfBoundsTimedelta,
#      16 )
#      18 from pandas.util.version import InvalidVersion
#      21 class IntCastingNaNError(ValueError):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/missing.pyx:40, in init pandas._libs.missing()
# ---> 40 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: partially initialized module 'pandas' from 'c:\Users\aimor\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)

# %%
import pandas as pd
# Series
# A pandas 1-Dimensional labeled array that can hold any data types
# Single column in spreadsheet (1-Dimentional) 
data = [100.00,120.50,130.50]
print(data)

num = pd.Series(data,index=["English","Tamil","Maths"])
# print(num)
# print(type(num))
print(num.iloc[2])
print(num.loc["Tamil"])
print(num)
# update
num["Tamil"]=200
print(num)
# Out:
# [100.0, 120.5, 130.5]
# 130.5
# 120.5
# English    100.0
# Tamil      120.5
# Maths      130.5
# dtype: float64
# English    100.0
# Tamil      200.0
# Maths      130.5
# dtype: float64

# %%
import pandas as pd
data = [100.00,120.50,130.50]
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 data = [100.00,120.50,130.50]
#       3 print(data)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
#      21     is_bool,
#      22     is_callable,
#    (...)     28     is_text,
#      29 )
# ---> 31 from pandas.errors import Pandas4Warning
#      33 # compute
#      35 use_bottleneck_doc = """
#      36 : bool
#      37     Use the bottleneck library to accelerate if it is installed,
#      38     the default is True
#      39     Valid values: False,True
#      40 """
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\errors\__init__.py:12
#       8 import ctypes
#      10 from pandas._config.config import OptionError
# ---> 12 from pandas._libs.tslibs import (
#      13     IncompatibleFrequency,
#      14     OutOfBoundsDatetime,
#      15     OutOfBoundsTimedelta,
#      16 )
#      18 from pandas.util.version import InvalidVersion
#      21 class IntCastingNaNError(ValueError):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\_libs\tslibs\__init__.py:41
#       1 __all__ = [
#       2     "BaseOffset",
#       3     "Day",
#    (...)     37     "tz_convert_from_utc_single",
#      38 ]
#      40 from pandas._libs.tslibs import dtypes
# ---> 41 from pandas._libs.tslibs.conversion import localize_pydatetime
#      42 from pandas._libs.tslibs.dtypes import (
#      43     Resolution,
#      44     periods_per_day,
#      45     periods_per_second,
#      46 )
#      47 from pandas._libs.tslibs.nattype import (
#      48     NaT,
#      49     NaTType,
#      50     iNaT,
#      51     nat_strings,
#      52 )
#
# File pandas/_libs/tslibs/conversion.pyx:1, in init pandas._libs.tslibs.conversion()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/offsets.pyx:1, in init pandas._libs.tslibs.offsets()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/timestamps.pyx:1, in init pandas._libs.tslibs.timestamps()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap>:648, in ModuleSpec.parent(self)
# --> 648     @property
#     649     def parent(self):
#     650         """The name of the module's parent."""
#     651         if self.submodule_search_locations is None:
#
# KeyboardInterrupt:

# %%
import pandas as pd
data = [100.00,120.50,130.50]
# data = [True,False]
# data= ["vivek","Harry"]
numb = pd.Series(data,index=["Mark-1","Mark-2","Mark-3"])
print(numb) # metadata

print(numb.iloc[2])
print(numb.loc["Mark-2"])
numb.loc["Mark-2"]=199
print(numb)
# print(type(numb))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 5
#       2 data = [100.00,120.50]
#       3 # data = [True,False]
#       4 # data= ["vivek","Harry"]
# ----> 5 numb = pd.Series(data,index=["Mark-1","Mark-2","Mark-3"])
#       6 print(numb) # metadata
#       8 print(numb.iloc[2])
#
# File /lib/python3.14/site-packages/pandas/core/series.py:503, in Series.__init__(self, data, index, dtype, name, copy)
#     501     index = default_index(len(data))
#     502 elif is_list_like(data):
# --> 503     com.require_length_match(data, index)
#     505 # create/copy the manager
#     506 if isinstance(data, SingleBlockManager):
#
# File /lib/python3.14/site-packages/pandas/core/common.py:601, in require_length_match(data, index)
#     597 """
#     598 Check the length of data matches the length of the index.
#     599 """
#     600 if len(data) != len(index):
# --> 601     raise ValueError(
#     602         "Length of values "
#     603         f"({len(data)}) "
#     604         "does not match length of index "
#     605         f"({len(index)})"
#     606     )
#
# ValueError: Length of values (2) does not match length of index (3)

# %%
import pandas as pd
data = [100,120,130]
# numb = pd.Series(data)
# print(numb) # metadata 

data = [100,120.00]
series = pd.Series(data)
print(series)
series = pd.Series(data,index=["a","b","c"])
# print(series) # metadata 
# update 
print(series)
series.loc["c"]=200
# print(series.loc["c"]) # metadata 
print(series.iloc[0]) # metadata
# Out:
# 0      100
# 1    120.0
# 2    vivek
# dtype: object
# a      100
# b    120.0
# c    vivek
# dtype: object
# 100

# %%
import pandas as pd
data = [100,120,130]
numb = pd.Series(data)
# print(numb) # metadata 


data = [100.1,3.14,130.50]
decimal = pd.Series(data)
# print(decimal) # metadata 


data = ["Vijay","Vivek"]
string = pd.Series(data)
# print(string) # metadata 

data = [True, False]
string = pd.Series(data)
# print(string) # metadata 


data = [100,120,130]
series = pd.Series(data,index=["a","b","c"])
# print(series) # metadata 

# accessing method
data = [100,120,130]
series = pd.Series(data,index=["a","b","c"])
# print(series.loc["c"]) # metadata 


# update 
data = [100,120,130]
series = pd.Series(data,index=["a","b","c"])
series.loc["c"]=200
# print(series) # metadata 

# accessing by index (i) 
data = [100,120,130]
series = pd.Series(data,index=["a","b","c"])
# print(series.iloc[2]) # metadata
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
data = [100,120,130,200,250]
series = pd.Series(data,index=["a","b","c","d","e"])
print(series)
print(series[series >= 130]) # metadata
# Out:
# a    100
# b    120
# c    130
# d    200
# e    250
# dtype: int64
# c    130
# d    200
# e    250
# dtype: int64

# %%
# filter method
data = [100,120,130,200,250]
series = pd.Series(data,index=["a","b","c","d","e"])
print(series[series >= 200]) # metadata 

# filter method
data = [100,120,130,200,250]
series = pd.Series(data,index=["a","b","c","d","e"])
print(series[series < 200]) # metadata
# Out:
# d    200
# e    250
# dtype: int64
# a    100
# b    120
# c    130
# dtype: int64

# %%
menu = {"Dosa":175,"Idly":55,"Coffee":25}
print(menu)
var1 = pd.Series(menu)
print(var1)
print(var1.iloc[0])
print(var1.loc["Dosa"])
# print(f"Cost of Idly :{var1.loc["Idly"]}")
# Out:
# {'Dosa': 175, 'Idly': 55, 'Coffee': 25}
# Dosa      175
# Idly       55
# Coffee     25
# dtype: int64
# 175
# 175

# %%
# dict to series
menu = {"Dosa":175,"Idly":55,"Coffee":25}
series = pd.Series(menu)

print(f"Cost of Idly :{series.loc["Idly"]}")

# series.loc["Idly"] += 6
print(series)
series = series.astype(float)
series.loc["Idly"] += 6.85
print(series)
# Out:
# Cost of Idly :55
# Dosa      175
# Idly       55
# Coffee     25
# dtype: int64
# Dosa      175.00
# Idly       61.85
# Coffee     25.00
# dtype: float64

# %%
menu = {"Dosa":175,"Idly":55,"Coffee":25}
num = pd.Series(menu)
print(num[num<=150])
#print(series[series <50])
# print(series)

var1=[{"Name":"Sab","Age":30,"Job":"BigData"}]
print(type(var1))
# Out:
# Idly      55
# Coffee    25
# dtype: int64
# <class 'list'>

# %%
data = {"Name":['Vivek','Vijay','Kasi','Sam','TD'],
        "Age":[30,32,29,38,30]
       }
df = pd.DataFrame(data)
print(df)
df1 = pd.DataFrame(data,index=["Friend 1", "Friend 2","Friend 3","Friend 4","Friend 5"])
print(df1)
# print(df.iloc[4])
# print(df1.loc["Friend 1"])
df1["Job"]=["SQL","DE","Devops","TL","ETL"]
# print(df1)

new_row = pd.DataFrame(
    [
    {"Name":"Sab","Age":30,"Job":"BigData"},{"Name":"Sab","Age":30,"Job":"BigData"}
    ],index=["Friend-6","Friend-7"])
# print(new_row)


# concat the new row to existing df
df2 = pd.concat([df1,new_row])
print(df2)
# Out:
#     Name  Age
# 0  Vivek   30
# 1  Vijay   32
# 2   Kasi   29
# 3    Sam   38
# 4     TD   30
#            Name  Age
# Friend 1  Vivek   30
# Friend 2  Vijay   32
# Friend 3   Kasi   29
# Friend 4    Sam   38
# Friend 5     TD   30
#            Name  Age      Job
# Friend 1  Vivek   30      SQL
# Friend 2  Vijay   32       DE
# Friend 3   Kasi   29   Devops
# Friend 4    Sam   38       TL
# Friend 5     TD   30      ETL
# Friend-6    Sab   30  BigData
# Friend-7    Sab   30  BigData

# %%
# dataFrame A tabular data structure with rows and columns (2 dimentional) similar to excel spreadsheet

data = {"Name":['Vivek','Vijay','Kasi','Sam','TD'],
        "Age":[30,32,29,38,30]
       }
df = pd.DataFrame(data)
print(df)
print(df.iloc[4])


df = pd.DataFrame(data,index=["Friend 1", "Friend 2","Friend 3","Friend 4","Friend 5"])

print(df)
print(df.loc["Friend 2"]) # locatoin by lable

print(df.iloc[4]) # locatoin by lable
# Out:
#     Name  Age
# 0  Vivek   30
# 1  Vijay   32
# 2   Kasi   29
# 3    Sam   38
# 4     TD   30
# Name    TD
# Age     30
# Name: 4, dtype: object
#            Name  Age
# Friend 1  Vivek   30
# Friend 2  Vijay   32
# Friend 3   Kasi   29
# Friend 4    Sam   38
# Friend 5     TD   30
# Name    Vijay
# Age        32
# Name: Friend 2, dtype: object
# Name    TD
# Age     30
# Name: Friend 5, dtype: object

# %%
# Add a new column 
data = {"Name":['Vivek','Vijay','Kasi','Sam','TD'],
        "Age":[30,32,29,38,30]
       }

df = pd.DataFrame(data,index=["Friend 1", "Friend 2","Friend 3","Friend 4","Friend 5"])
print(type(df))
df["Job"]=["SQL","DE","Devops","TL","ETL"]
print(df)

new_row = pd.DataFrame(
    [
    {"Name":"Sab","Age":30,"Job":"BigData"}
    ],index=["Friend-6"])
print(new_row)
print(type(new_row))
print(df)

# concat the new row to existing df
df1 = pd.concat([df,new_row])
print(df1)
# Out:
# <class 'pandas.DataFrame'>
#            Name  Age     Job
# Friend 1  Vivek   30     SQL
# Friend 2  Vijay   32      DE
# Friend 3   Kasi   29  Devops
# Friend 4    Sam   38      TL
# Friend 5     TD   30     ETL
#          Name  Age      Job
# Friend-6  Sab   30  BigData
# <class 'pandas.DataFrame'>
#            Name  Age     Job
# Friend 1  Vivek   30     SQL
# Friend 2  Vijay   32      DE
# Friend 3   Kasi   29  Devops
# Friend 4    Sam   38      TL
# Friend 5     TD   30     ETL
#            Name  Age      Job
# Friend 1  Vivek   30      SQL
# Friend 2  Vijay   32       DE
# Friend 3   Kasi   29   Devops
# Friend 4    Sam   38       TL
# Friend 5     TD   30      ETL
# Friend-6    Sab   30  BigData

# %%
# Add a new column 
data = {"Name":['Vivek','Vijay','Kasi','Sam','TD'],
        "Age":[30,32,29,38,30]
       }

df = pd.DataFrame(data,index=["Friend 1", "Friend 2","Friend 3","Friend 4","Friend 5"])

df["Job"]=["SQL","DE","Devops","TL","ETL"]
print(df)

# Add a new row

new_row = pd.DataFrame(
    [
    {"Name":"Sab","Age":30,"Job":"BigData"}
    ])

# concat the new row to existing df
df1 = pd.concat([df,new_row])
print(df1)
# Out:
#            Name  Age     Job
# Friend 1  Vivek   30     SQL
# Friend 2  Vijay   32      DE
# Friend 3   Kasi   29  Devops
# Friend 4    Sam   38      TL
# Friend 5     TD   30     ETL
#            Name  Age      Job
# Friend 1  Vivek   30      SQL
# Friend 2  Vijay   32       DE
# Friend 3   Kasi   29   Devops
# Friend 4    Sam   38       TL
# Friend 5     TD   30      ETL
# 0           Sab   30  BigData

# %%
# Add new rows

# Add a new column 
data = {"Name":['Vivek','Vijay','Kasi','Sam','TD'],
        "Age":[30,32,29,38,30]
       }

df = pd.DataFrame(data,index=["Friend 1", "Friend 2","Friend 3","Friend 4","Friend 5"])

df["Job"]=["SQL","DE","Devops","TL","ETL"]
print(df)

# Add a new row

new_row = pd.DataFrame(
    [{"Name":"Kishore","Age":30,"Job":"BA"},
     {"Name":"Manoj","Age":30,"Job":"Snowflake"}    
    ]
    
    ,index=["Firend 6","Firend 7"])

# concat the new row to existing df
df = pd.concat([df,new_row])
print(df)
# Out:
#            Name  Age     Job
# Friend 1  Vivek   30     SQL
# Friend 2  Vijay   32      DE
# Friend 3   Kasi   29  Devops
# Friend 4    Sam   38      TL
# Friend 5     TD   30     ETL
#              Name  Age        Job
# Friend 1    Vivek   30        SQL
# Friend 2    Vijay   32         DE
# Friend 3     Kasi   29     Devops
# Friend 4      Sam   38         TL
# Friend 5       TD   30        ETL
# Firend 6  Kishore   30         BA
# Firend 7    Manoj   30  Snowflake

# %%
# import csv and json with pandas
import pandas as pd
df = pd.read_csv("friends_new.csv") # read_csv() function
# print(df.head())
# print(df)
# print(df.to_string())
# selecitng by columns

# print(df["Name"].to_string()) # skip truncated rows
# print(df["Age"].to_string())
# print(df[["Name","Age","Job"]].to_string())
# Out:
#                Name  Age              Job
# 0      Kavya Sharma   38  Sales Executive
# 1    Ishaan Agarwal   55   Data Scientist
# 2       Aditi Kumar   34  Sales Executive
# 3        Rahul Bhat   55       Consultant
# 4       Vivek Verma   21       Accountant
# ..              ...  ...              ...
# 995        Uma Iyer   41   Data Scientist
# 996    Aditya Reddy   22  Project Manager
# 997    Varun Kapoor   38           Doctor
# 998      Kiran Iyer   22  Product Manager
# 999    Uma Malhotra   35  Product Manager
#
# [1000 rows x 3 columns]

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
# and helps to filter the df using names keyword arguments
# print(df.iloc[0:2])
#rows       start:end:step ( end will not satisfy)
#columns    start:end:step ( end will not satisfy)
#print(df.iloc[0:2,0:2])
#print(df.iloc[:,0:2])
# print(df.iloc[0:3,:])
print(df)
print("----------")
print(df.iloc[::1,::3])
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# ----------
#        SNO  IsMarried
# Name
# Vivek    1          0
# Sam      2          1
# Kasi     3          1
# TD       4          1
# Manoj    5          1
# Deena    6          0

# %%
# selection by rows
# df = pd.read_csv("Friends.csv",index_col="Name") # ascending rows by Name 
import pandas as pd
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
# and helps to filter the df using names keyword arguments
print(df)
# print(df.loc["Vivek"])
# print(df.loc["TD"])
print("------------------------------------")
# print(df.loc["TD"])
# print(df.loc["TD":"Manoj",["Job","Age"]]) # range of filters
try:
    print(df.iloc[0:5:0,0:2]) # filtering the first 2 columns in the select
except:
    print("Please check Index Location")
print(df.iloc[0:5,0:3])
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# ------------------------------------
# Please check Index Location
#        SNO  Age  Job
# Name
# Vivek    1   40   DE
# Sam      2   28   DA
# Kasi     3   29   DE
# TD       4   30  ETL
# Manoj    5   30   DE

# %%
# exception handling 
friend = input("Enter a firend Name:")
try:
    print(df.loc[friend])
except KeyError:
    print(f"{friend} not found")
# Out:
# Enter a firend Name: ddb
# ddb not found

# %%
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
# and helps to filter the df using names keyword arguments
# print(df)

# series[series<200] 

#print(df[df["Age"]>=30])
# print(df[df["IsMarried"]==True])

filter_df_and = df[ (df["Age"]>=30) & (df["IsMarried"]== False)]
print(filter_df_and)
filter_df_or = df[ (df["Age"]>=30) & (df["IsMarried"]== True)]
print(filter_df_or)
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Deena    6   30  Faculty          0  Aimore
#        SNO  Age  Job  IsMarried Company
# Name
# TD       4   30  ETL          1     NaN
# Manoj    5   30   DE          1     HCL

# %%
# filtering using pandas : keeping the rows that match conditions
df = pd.read_csv("Friends.csv",index_col="Name") # ascending rows by Name 

df = df.iloc[:,0:4]
print(df)
old_friend = df[df["Age"]>= 29]
print(old_friend)
young_friend = df[df["Age"]<=28]
print(young_friend)
married_young_friend = df[(df["IsMarried"] ==True ) | (df["Age"] <=29 )  ]
print(married_young_friend)
unmarried_old_firend = df[(df["IsMarried"] ==False ) & (df["Age"] >30 )  ]
print(unmarried_old_firend)
# Out:
#        SNO  Age      Job  IsMarried
# Name
# Vivek    1   40       DE          0
# Sam      2   28       DA          1
# Kasi     3   29       DE          1
# TD       4   30      ETL          1
# Manoj    5   30       DE          1
# Deena    6   30  Faculty          0
#        SNO  Age      Job  IsMarried
# Name
# Vivek    1   40       DE          0
# Kasi     3   29       DE          1
# TD       4   30      ETL          1
# Manoj    5   30       DE          1
# Deena    6   30  Faculty          0
#       SNO  Age Job  IsMarried
# Name
# Sam     2   28  DA          1
#        SNO  Age  Job  IsMarried
# Name
# Sam      2   28   DA          1
# Kasi     3   29   DE          1
# TD       4   30  ETL          1
# Manoj    5   30   DE          1
#        SNO  Age Job  IsMarried
# Name
# Vivek    1   40  DE          0

# %%
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")

print(df)
print(df.count())
print(df.mean(numeric_only=True)) # average
print(df.sum(numeric_only=True))
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# SNO          6
# Age          6
# Job          6
# IsMarried    6
# Company      4
# dtype: int64
# SNO           3.500000
# Age          31.166667
# IsMarried     0.666667
# dtype: float64
# SNO           21
# Age          187
# IsMarried      4
# dtype: int64

# %%
# aggregate functions - Reduces a set of values into single summary values
# used to summarize and analyze data and often used with the groupby() functions
# this function will apply to whole data frame
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
print(df)
print("-------------------------")
print(df.mean(numeric_only=True)) # average
print(df.sum(numeric_only=True)) # sum
print(df.min(numeric_only=True)) # min
print(df.max(numeric_only=True)) # max
print(df.count()) # count
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# -------------------------
# SNO           3.500000
# Age          31.166667
# IsMarried     0.666667
# dtype: float64
# SNO           21
# Age          187
# IsMarried      4
# dtype: int64
# SNO           1
# Age          28
# IsMarried     0
# dtype: int64
# SNO           6
# Age          40
# IsMarried     1
# dtype: int64
# SNO          6
# Age          6
# Job          6
# IsMarried    6
# Company      4
# dtype: int64

# %%
# single column aggregate function
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
print(df)
print("-------------------------")
print(df["Age"].mean()) # average
print(df["Age"].sum()) # sum
print(df["Age"].min()) # min
print(df["Age"].max()) # max
print(df["Age"].count()) # count
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# -------------------------
# 31.166666666666668
# 187
# 28
# 40
# 6

# %%
# group by function
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\friends_new.csv", index_col="Name")
# print(df)
# select department_name,avg(salary) from empl group by department_name
print("-------------------------")
group_df = df.groupby("Job")
#print(group_df["Age"].mean())
# print(group_df["Age"].sum())
#print(group_df["Age"].min())
#print(group_df["Age"].max())
print(group_df["Age"].count())
# Out:
# -------------------------
# Job
# Accountant           48
# Architect            53
# Bank Manager         60
# Business Analyst     54
# Civil Engineer       39
# Consultant           56
# Data Analyst         51
# Data Scientist       47
# Designer             47
# DevOps Engineer      41
# Doctor               65
# HR Manager           48
# Lawyer               55
# Marketing Manager    37
# Product Manager      50
# Project Manager      51
# QA Engineer          50
# Sales Executive      62
# Software Engineer    42
# Teacher              44
# Name: Age, dtype: int64

# %%
# Data Cleaning: process of fixing 
# and removing (incomplete, incorrect,or irreleavant data)
# 75% of work is done with pandas is data cleaning

# %%
# drop irreleavant columns
import pandas as pd
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
print(df)
print("-------------------------")
# df = df.drop(columns=["IsMarried"])
df = df.drop(columns=["IsMarried","SNO"])
print(df)
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# -------------------------
#        Age      Job Company
# Name
# Vivek   40       DE     GXS
# Sam     28       DA     TCS
# Kasi    29       DE     NaN
# TD      30      ETL     NaN
# Manoj   30       DE     HCL
# Deena   30  Faculty  Aimore

# %%
# handle missing data 
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
print(df)
print("-------------------------")
# df = df.dropna(subset=["Company"])
df = df.fillna({"Company":"None"})
df = df.fillna({"Job":"None"})
print(df)


# coalesce(value1,"None")
# slecet coalesce(column,'None')
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29      NaN          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# -------------------------
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29     None          1    None
# TD       4   30      ETL          1    None
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore

# %%
# fix inconsistent values
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
print(df)
print("-------------------------")
df["Job"]=df["Age"].replace({"DE":"Data Engineer"
                            ,"DA":"Data Analyst"
                            ,"Faculty":"Trainee"
                            })
print(df2)
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# -------------------------
# Name
# Vivek    Data Engineer
# Sam       Data Analyst
# Kasi     Data Engineer
# TD                 ETL
# Manoj    Data Engineer
# Deena          Trainee
# Name: Job, dtype: str

# %%
# standardize text
df = pd.read_csv(r"C:\Users\aimor\Downloads\Github\Aimore\Aimore\Python\Files\Friends.csv", index_col="Name")
print(df)
print("-------------------------")
df["Company"]=df["Company"].str.upper()
df["Job"]=df["Job"].str.lower()
print(df)
# Out:
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       DE          0     GXS
# Sam      2   28       DA          1     TCS
# Kasi     3   29       DE          1     NaN
# TD       4   30      ETL          1     NaN
# Manoj    5   30       DE          1     HCL
# Deena    6   30  Faculty          0  Aimore
# -------------------------
#        SNO  Age      Job  IsMarried Company
# Name
# Vivek    1   40       de          0     GXS
# Sam      2   28       da          1     TCS
# Kasi     3   29       de          1     NaN
# TD       4   30      etl          1     NaN
# Manoj    5   30       de          1     HCL
# Deena    6   30  faculty          0  AIMORE
