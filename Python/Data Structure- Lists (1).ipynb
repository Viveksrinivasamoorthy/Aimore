# %%
# list - []
# tuple - ()
# sets - {}
# dictionary - {} - key,value

# list 
# 1. used to store for temporary storage
# add, modify, remove (immutable)
# it is unordered

list1 = [10,"Vivek",7.9,True]
print(list1)
print(type(list1))

list2 = [10,20,30,40,50]

print(list2[0])
print(list2[-1])
print(list2[2:4])
print(list2[1:])
print(list2[0:])
print(list2[1:4])
print(list2[::2])
print(list2[::-1])
print(list2[-1:-3:-1])

# modify
list2[0]=100
print(list2)

# list2[5]=100
print(list2)

# insert
list2.insert(2,"vivek")
print(list2)

# append
list2.append(100)
print(list2)

# pop  remove the alst element
list2.pop()
print(list2)

list2.remove("vivek")
print(list2)

# extend
list2.extend([200,300])
print(list2)

list2.sort()
print(list3)


list3 = sorted(list2)
list3 = sorted(list2, reverse=False)
list3 = sorted(list2, reverse=True)

print(list3)

print(min(list3),max(list3),len(list3),sum(list3))


# methods
# append
# access
# modify
# insert
# extend
# remove
# sort 

# function
#sum
#min
#max
#
#len
#all
#any
# sorted
# Out:
# [10, 'Vivek', 7.9, True]
# <class 'list'>
# 10
# 50
# [30, 40]
# [20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [20, 30, 40]
# [10, 30, 50]
# [50, 40, 30, 20, 10]
# [50, 40]
# [100, 20, 30, 40, 50]
# [100, 20, 30, 40, 50]
# [100, 20, 'vivek', 30, 40, 50]
# [100, 20, 'vivek', 30, 40, 50, 100]
# [100, 20, 'vivek', 30, 40, 50]
# [100, 20, 30, 40, 50]
# [100, 20, 30, 40, 50, 200, 300]
# [300, 200, 100, 50, 40, 30, 20]
# [300, 200, 100, 50, 40, 30, 20]
# 20 300 7 740

# %%
# helps to check the quality of list 
# all() -> AND
# any() -> OR

# Falsy value: 0,"",None,[],(),False

list1 = [0,None,False,"",10]
print(any(list1))
print(all(list1))

list1 = [10,20,30,[]]
print(any(list1))
print(all(list1))

print(len(list1))
# Out:
# True
# False
# True
# False
# 4
