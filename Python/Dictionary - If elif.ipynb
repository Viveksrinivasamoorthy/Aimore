# %%
# dictionary - {} - key,value

subjects = ["English", "Math", "Science"];
marks = [85, 90, 78];



student_grades = {"English": 85, "Math": 90, "Science":78}

print(type(subjects)) 
print(type(marks)) 
print(type(student_grades)) 

# get(), keys() values() items() update() pop() popitem() clear()  setdefault() - returns the value for the specified key if key is in dictionary, else default_value. If default_value is not provided, it returns None.

# get(key,default_value) - returns the value for the specified key if key is in dictionary, else default_value. If default_value is not provided, it returns None.
print(student_grades.get("Math"))
print(student_grades.get("English"))
print(student_grades.get("Tamil"))
print(student_grades.get("Tamil","Not Found"))

print(student_grades.keys())
print(student_grades.values())
print(student_grades.items())


# isnull(age,0)
# coalesce(name,"Unknown")

# update() - updates the dictionary with the specified key-value pairs. If the key already exists, its value is updated; if the key does not exist, a new key-value pair is added.
student_grades.update({"Math": 100})
print(student_grades.get("Math"))
print(student_grades.items())
student_grades.update({"Tamil": 95})
print(student_grades.items())



# pop(key) - removes the specified key and returns its value. If the key does not exist, it raises a KeyError.
print(student_grades.pop("Tamil"))
print(student_grades)
#popitem() - removes and returns the last inserted key-value pair as a tuple. If the dictionary is empty, it raises a KeyError.

print(student_grades.popitem())
print(student_grades)


student_grades.clear()
print(student_grades)


student_grades = {"History":88}
print(student_grades)
student_grades.setdefault("Math", 90)
print(student_grades)
student_grades.update({"Math": 100,"English": 85,"Science": 78,"Geography": 92})
print(student_grades)
# print(math_marks)

# uniqueness between update and setdefault
# if the key exists, value get updated 
# if the key does not exist, value is added

# difference with syntax - update() takes a dictionary as an argument, while setdefault() takes a key and a default value as arguments.

# creating dict using two lists - dict(zip(keys, values)) - creates a dictionary by zipping two lists together, where the first list contains the keys and the second list contains the corresponding values.

#dict(zip(keys,value))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'dict'>
# 90
# 85
# None
# Not Found
# dict_keys(['English', 'Math', 'Science'])
# dict_values([85, 90, 78])
# dict_items([('English', 85), ('Math', 90), ('Science', 78)])
# 100
# dict_items([('English', 85), ('Math', 100), ('Science', 78)])
# dict_items([('English', 85), ('Math', 100), ('Science', 78), ('Tamil', 95)])
# 95
# {'English': 85, 'Math': 100, 'Science': 78}
# ('Science', 78)
# {'English': 85, 'Math': 100}
# {}
# {'History': 88}
# {'History': 88, 'Math': 90}
# {'History': 88, 'Math': 100, 'English': 85, 'Science': 78, 'Geography': 92}

# %%
subjects = ["English", "Math", "Science"];
marks = [85, 90, 78];

dict2 = dict(zip(subjects, marks))
print(dict2)
# Out:
# {'English': 85, 'Math': 90, 'Science': 78}

# %%
# copy() - creates a shallow copy of the dictionary. The new dictionary will have the same key-value pairs as the original dictionary, but it will be a separate object in memory.

# shallow copy & Deep copy - shallow copy creates a new object but does not create copies of nested objects, while deep copy creates a new object and recursively copies all nested objects.
# import copy

org1 = {"Person":{"name": "Vivek"}, "role": "Developer"}
shallow1 = org1.copy()
shallow1["role"] = "Manager"
shallow1["Person"]["name"] = "Aimore"
# deep = copy.deepcopy(org1)

print(shallow1,org1)
# print(deep)
# Out:
# {'Person': {'name': 'Aimore'}, 'role': 'Manager'} {'Person': {'name': 'Aimore'}, 'role': 'Developer'}

# %%
original = "vivek"
localvar = original
localvar = "Aimore"
print(original,localvar)
# Out:
# vivek Aimore

# %%
import copy as cp
original = "vivek"
shallowcopy = cp.copy(original)
shallowcopy = "Aimore"
print(original,shallowcopy)
# Out:
# vivek Aimore

# %%
import copy as cp
original = "vivek"
shallowcopy = cp.copy(original)
deepcopy = cp.deepcopy(original)
shallowcopy = "Aimore"
deepcopy = "Aimore"
print(original,shallowcopy,deepcopy)
# Out:
# vivek Aimore Aimore

# %%
# control statements - if, else, elif, nested if
# looping statement

# if 

age = 20
result = ""

if age>18: # if true, execute the block of code inside the if statement
    result = "Adult"

print(result)


# if else

if age >18:
    result = "Adult"
else:
    result = "Minor"
    
print(result)
# Out:
# Adult
# Adult

# %%
# elif
marks = 90

if marks >= 90:
    result = "A"
elif marks > 80:
    result = "B"
elif marks > 70:
    result = "C"
else:
    result = "Fail"

print(result)
# Out:
# A

# %%
age = 20
elegibletovote = True 

if age >=18:
    print("Adults")
    if elegibletovote:
        print("Eligible to vote")
else:
    print("Minor")
# Out:
# Adults
# Eligible to vote

# %%
age = 20
elegibletovote = True 

if age >=18 and elegibletovote:
    result = "Eligible to vote"
print(result)
# Out:
# Eligible to vote
