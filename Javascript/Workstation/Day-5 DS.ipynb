// %%
let students_name = ["vivek","vijay","kasi"]
let students_age = [36,35,33]

console.log(students_name[1])
console.log(students_age[1])
console.log(typeof(students_age[1]))
// Out:
// vijay
// 35
// number

// %%
// objects 

let names = "Vivek"
let age = 30
let Job = "DE"
console.log(names)

let students_name = ["vivek","vijay","kasi"]
let students_age = [36,35,33]

console.log(students_name[1])


let faculty = {name:"Vivek",
                age: 35,
                job:"DE"
}
console.log(faculty)
console.log(typeof(faculty))


console.log(faculty.name)
console.log(typeof(faculty.name))
console.log(faculty.age)
console.log(typeof(faculty.age))
console.log(faculty.job)

console.log(faculty["name"])
console.log(faculty["age"])
console.log(faculty["job"])
// Out:
// Vivek
// vijay
// { name: "Vivek", age: 35, job: "DE" }
// object
// Vivek
// string
// 35
// number
// DE
// Vivek
// 35
// DE

// %%
let faculty = {name:"Vivek",
                age: 35,
                job:"DE"
}
// Out:
// 3 [Function: values]

// %%
// update method
console.log(faculty["age"])
faculty.age = 36
faculty["age"]=37
console.log(faculty["age"])
// Out:
// 36
// 37

// %%
// adding new property
console.log(faculty)
faculty.exp = 11
console.log(faculty)
faculty.gender = "male"
console.log(faculty)
// Out:
// { name: "Vivek", age: 37, job: "DE", exp: 11 }
// { name: "Vivek", age: 37, job: "DE", exp: 11 }
// { name: "Vivek", age: 37, job: "DE", exp: 11, gender: "male" }

// %%
// delete

delete faculty.gender;
console.log(faculty)
// Out:
// { name: "Vivek", age: 37, job: "DE", exp: 11 }

// %%
// array  + objects

let students = [{name:"vivek",age:20,mark:85},{name:"vijay",age:20,mark:95}]
console.log(students.length)
// Out:
// 2

// %%
// accessing methods
console.log(students[0])
console.log(students[1])

console.log(students[0].name)
console.log(students[1].age)
// Out:
// { name: "vivek", age: 20, mark: 85 }
// { name: "vijay", age: 20, mark: 95 }
// vivek
// 20

// %%
// looping array of objects

for (let i = 0;i<students.length;i++)
{
    console.log(students[i].name,students[i].age)
}
// Out:
// vivek 20
// vijay 20

// %%
let students_scores = [{name:"vijay",mark:85},{name:"kasi",mark:95},{name:"sam",mark:65},{name:"TD",mark:70}]

let i=0
for ( i = 0; i<students_scores.length; i++)
{
    if (students_scores[i].mark<85)
    {
        console.log(students_scores[i].name)
    }

}
// Out:
// sam
// TD

// %%
// nested arrays
let matrix = [
    [10,20,30],
    [40,50,60],
    [70,80,90]
]
console.log(matrix)
console.log(matrix[0])
console.log(matrix[1])
console.log(matrix[2])

console.log(matrix[0][1])
// Out:
// [ [ 10, 20, 30 ], [ 40, 50, 60 ], [ 70, 80, 90 ] ]
// [ 10, 20, 30 ]
// [ 40, 50, 60 ]
// [ 70, 80, 90 ]
// 20

// %%
// nested loops
let i = 0;

let matrix = [
    [10,20,30],
    [40,50,60],
    [70,80,90]
]

for (i=0;i<matrix.length;i++)
{
  
    console.log(matrix[i])
    for (let j=0;j<matrix[i].length;j++)
    {
     
        console.log(matrix[i][j])
    }
}
// Out:
// [ 10, 20, 30 ]
// 10
// 20
// 30
// [ 40, 50, 60 ]
// 40
// 50
// 60
// [ 70, 80, 90 ]
// 70
// 80
// 90

// %%
// objects inside objects

let students = {name:"vijay",age:20,address:{city:"chennai",state:"TN",pincode:600000}}
console.log(students)

console.log(students.address.state)
// Out:
// {
//   name: "vijay",
//   age: 20,
//   address: { city: "chennai", state: "TN", pincode: 600000 }
// }
// TN

// %%
// object inside array

let students = {name:"vijay", subjects:["Maths","English","Tamil"],marks:[80,90,70]}
console.log(students)
console.log(students.subjects[1])
console.log(students.marks[1])
// Out:
// {
//   name: "vijay",
//   subjects: [ "Maths", "English", "Tamil" ],
//   marks: [ 80, 90, 70 ]
// }
// English
// 90
