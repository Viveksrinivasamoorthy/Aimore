# %%
# arithmetic operator
# +, -, *, /, %, //, **

a=11
b=3
# print("a + b | ",a," + ",b," = ",a+b)
print(f"a + b | {a} + {b} = {a+b}")
print(f"a - b | {a} - {b} = {a-b}")
print(f"a / b | {a} / {b} = {a/b}")
print(f"a * b | {a} * {b} = {a*b}")
print(f"a // b | {a} // {b} = {a//b}")
print(f"a ** b | {a} ** {b} = {a**b}")
print(f"a % b | {a} % {b} = {a%b}")
# print(f"Value of a is:{ a     }")
# a + b | 10 + 5 = 15
# Out:
# a + b | 11 + 3 = 14
# a - b | 11 - 3 = 8
# a / b | 11 / 3 = 3.6666666666666665
# a * b | 11 * 3 = 33
# a // b | 11 // 3 = 3
# a ** b | 11 ** 3 = 1331
# a % b | 11 % 3 = 2

# %%
# assignment operator
# =, +=, -=, *=, /=, //=, **=, %=

a=11
b=3
# Out:
# 14
# 14
