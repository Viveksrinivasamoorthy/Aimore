// %%
// Data Structure
// array


let age = 30
let name='vivek'
let isfaculty = true

let var1 = [30,"vivek",false]
console.log(typeof(var1))
console.log(var1[0])
console.log(var1)

console.log(typeof(list))
console.log(list.length)

// indexing -> always starts with 0
// length starts with 1
//      0   1   2   3
//array 10, 20, 30, 40


// array - access method
console.log(list[0])
console.log(list[1])
console.log(list[2])
// Out:
// object
// 30
// [ 30, "vivek", false ]
// object
// 3
// 10
// 20
// 30

// %%
// 0-10
// 1-20
// 2-30
//length of array = 3
let array =  [30,"vivek",false]
for (let i=0; i<array.length; i++)
{
    // console.log(array[i])
    // console.log(typeof(array[i]))
    console.log("Index position:",i," Type of value is:",typeof(array[i]))
}
console.log(typeof(array))
// Out:
// Index position: 0  Type of value is: number
// Index position: 1  Type of value is: string
// Index position: 2  Type of value is: boolean
// object

// %%
let age = array[0]
console.log(age)
// Out:
// 30

// %%
// array - update
array[1] = "vijay"
console.log(array[1])
// Out:
// vijay

// %%
// push() -> adding new element at the end
// shift()
// unshift()
// pop()
// length
// indexof()
// includes()

array =  [30,"vivek",false]
console.log(array)

array.push("Male")
console.log(array)

array.unshift("Employee")
console.log(array)

array.shift()
console.log(array)

array.pop()
console.log(array)

array.unshift("Employee")
console.log(array)

console.log(array.length)

console.log(array.indexOf(30))

console.log(array.includes("vivek"))
// Out:
// [ 30, "vivek", false ]
// [ 30, "vivek", false, "Male" ]
// [ "Employee", 30, "vivek", false, "Male" ]
// [ 30, "vivek", false, "Male" ]
// [ 30, "vivek", false ]
// [ "Employee", 30, "vivek", false ]
// 4
// 1
// true

// %%
1) Finding total of array CSSFontFeatureValuesRule
marks = [65,57,89,90,75]
2) average/ total
